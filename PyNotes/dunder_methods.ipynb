# %%
class _Test:
    name_usr = 'ravi'
    def __init__(self):
        print(self.name_usr)
        print(self.__init__)

print(_Test())
# Out:
# ravi
# <bound method _Test.__init__ of <__main__._Test object at 0x10a5fe270>>
# ...
